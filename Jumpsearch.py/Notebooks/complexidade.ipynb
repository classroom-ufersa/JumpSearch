# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n = np.arange(0, 1000, 1)

#print(n)

# %%
Tn_linear = n
Tn_log = np.log2(n)
Tn_jump = np.sqrt(n)
# Out:
# C:\Users\Moises\AppData\Local\Temp\ipykernel_12452\2747994095.py:2: RuntimeWarning: divide by zero encountered in log2
#   Tn_log = np.log2(n)

# %%
plt.plot(Tn_linear, label='Linear')
plt.plot(Tn_jump, label='raiz')
plt.plot(Tn_log, label='Log')
plt.xlabel('Tamanho da entrada')
plt.ylabel('Operações da CPU')
plt.title('Comparativo complexidade')
plt.legend()
plt.grid()

fig = plt.gcf()
#fig.savefig('Figura.png')

plt.show()

# %%
plt.plot(Tn_jump, label='raiz')
plt.xlabel('Tamanho da entrada')
plt.ylabel('Operações da CPU')
plt.title('Complexidade')
plt.legend()
plt.grid()

fig = plt.gcf()
fig.savefig('Jump.png')

plt.show()
